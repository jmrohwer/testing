# %%
import sys
print(sys.prefix)
print(sys.version)
print(sys.executable)
# Out:
# /usr
# 3.11.3 (main, Apr  5 2023, 15:52:25) [GCC 12.2.1 20230201]
# /usr/bin/python

# %%
import sysconfig
sysconfig.get_paths()
# Out:
# {'stdlib': '/usr/lib/python3.11',
#  'platstdlib': '/usr/lib/python3.11',
#  'purelib': '/usr/lib/python3.11/site-packages',
#  'platlib': '/usr/lib/python3.11/site-packages',
#  'include': '/usr/include/python3.11',
#  'platinclude': '/usr/include/python3.11',
#  'scripts': '/usr/bin',
#  'data': '/usr'}

# %%
import pysces
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pysces
#
# ModuleNotFoundError: No module named 'pysces'

# %%
pysces.test(3)
# Out:
# Copying pysces_test models if necessary ...
# src : /home/jr/src/git/pysces/pysces/pscmodels
# dest: /home/jr/Pysces/psc
# ........
# ----------------------------------------------------------------------
# Ran 8 tests in 0.006s
#
# OK
# done.
#
# Level 1 tests
# ......
# Level 2 tests
# ......
# ----------------------------------------------------------------------
# Ran 12 tests in 0.414s
#
# OK
# .....
# Level 3 tests
# ..
# ----------------------------------------------------------------------
# Ran 7 tests in 0.206s
#
# OK

# %%
import os
d = os.getcwd()

# %%
d
# Out:
# '/home/jr/src/git/testing/notebook1'

# %%
m = pysces.model('lin4', d)
# Out:
# Assuming extension is .psc
# Using model directory: /home/jr/src/git/testing/notebook1
# /home/jr/src/git/testing/notebook1/lin4.psc loading .....
# Parsing file: /home/jr/src/git/testing/notebook1/lin4.psc
#
# Calculating L matrix . . . . . . .  done.
# Calculating K matrix . . . . . . .  done.

# %%
m.doSimPlot()
# Out:
# LSODA time for 21 points: 0.0058362483978271484
# /usr/lib/python3.11/site-packages/scipy/integrate/_odepack_py.py:251: ODEintWarning: Integration successful.
#   warnings.warn(warning_msg, ODEintWarning)
# <img src="data:image/png;base64,..." width="640">

# %%
m.mode_integrator = 'CVODE'

# %%
m.doSimPlot()
# Out:
# CVODE time for 21 points: 0.005713462829589844
# <img src="data:image/png;base64,..." width="640">

# %%
m2 = pysces.model('debug_events', d)
# Out:
# Assuming extension is .psc
# Using model directory: /home/jr/src/git/testing/notebook1
# /home/jr/src/git/testing/notebook1/debug_events.psc loading .....
# Parsing file: /home/jr/src/git/testing/notebook1/debug_events.psc
#
# Calculating L matrix . . . . . . .  done.
# Calculating K matrix . . . . . . .  done.
#
# Event(s) detected.
#
# INFO: events detected and we have Assimulo installed,
# switching to CVODE (mod.mode_integrator='CVODE').

# %%
m2.doSimPlot(points=200)
# Out:
# event event1 is evaluating at 2.0070134539882303
# event event1 is assigning at 2.0070134539882303 (delay=0.0)
#
# event event2 is evaluating at 2.0070134539882303
# event event2 is assigning at 2.0070134539882303 (delay=0.0)
#
# event event3 is evaluating at 2.0070134539882303
# event event3 is assigning at 2.0070134539882303 (delay=0.0)
# executing event2
# executing event3
# executing event1
# CVODE time for 203 points: 0.01237940788269043
# <img src="data:image/png;base64,..." width="640">

# %%
import dill

# %%
import sortedcontainers

# %%
import identifiability
# Out:
# module 'multiprocessing_on_dill' is not installed
